# %% [markdown]
# <br>
# Numa estrutura real, cada schema estaria relacionado ao seu respectivo contâiner de data lake:
#
# - `raw`: arquivos CSV
# - `refined` e `curated`: arquivos Parquet com camada transacional Delta
# <br><br>

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS raw;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS refined;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS curated;
